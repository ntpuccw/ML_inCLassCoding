# %% [markdown]
# <hr>
#
# #### <strong>第一次專題：人臉辨識評比實驗</strong>
#
# 學號：
#
# 姓名：

# %% [markdown]
# <hr>
#
#  **<font color=darkgoldenrod>作品目標</font>**：
#
# 本作品採用四種方法進行人臉影像資料的分類（辨識）學習（訓練）並以測試資料進行評比。其中四種方法分別為：
#
# - 統計學習之多元羅吉斯回歸 MLR (Multinomial Logistic Regression)
#
# - 統計學習之支援向量機 SVM (Support Vector Machine)
#
# - 深度學習之神經網路 Pytorch (Neural Network) or CNN (Convolutional Neural Network)
# - 深度學習之人臉辨識產品：PyTorch Facenet (Deep Learning Face Recognition)
#
# 人臉影像資料：來自 Yale Face 38 人的人臉影像共 2410 張，每張大小 168×192（寬 x 高）。
#
#
# **<font color=darkgoldenrod>評比實驗計畫</font>**：<font color=red>（以下內容僅供參考，同學們務必以作者的語氣與實際計畫全面改寫）</font>
#
# 在此寫下你的評比實驗計畫，譬如：
# - 將使用原始人臉影像或 Eigenfaces 進行分訓練和評比。
# - 如何選擇分類器的演算法（Algorithm, solver）和其他超參數，是否使用交叉驗證來選擇最佳參數。
# - 評比指標的選擇，例如使用準確率、精確率、召回率和 F1 分數等指標來評估分類器的表現。（除準確率外，若其他指標沒有提供其他有意義的訊息，便不需加入）
# - 、、、

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod>預先載入套件：</font>**

# %%
import scipy.io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **<font color=darkgoldenrod>預先載入共用函數（def）</font>**

# %%
# 自訂之共用函數（def）可以放在這裡（函數名稱自取，但必須符合函數目的），譬如：
def common_function1():
    # 譬如載入資料的程式碼
    return data

def common_function2():
    # 譬如進行 PCA 或 SVD 的程式碼
    return processed_data

def common_function3():
    # 譬如訓練分類器的程式碼
    return model

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod> 0：人臉影像資料 Yale Face 之觀察與前處理</font>**
#
# 在此寫下你對 Yale Face 影像資料集的觀察與分析，譬如：
# - 資料的載入與前處理。
# - 製做另一組主成分資料供比較之用。
# - 、、、
# <hr>

# %%
# Yale Faces 資料集的載入
import pickle

with open('data/YaleFaces.pkl', 'rb') as f:
    data_dict = pickle.load(f)

X = data_dict['X'] # features
y = data_dict['y'] # labels，每人張數不同
img_w = data_dict['img_w'] # 圖片寬度
img_h = data_dict['img_h'] # 圖片高度

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod>1：統計學習之多元羅吉斯回歸</font>**
# <font color=red>（以下內容僅供參考，同學們務必以作者的語氣與實際計畫全面改寫）</font>
#
# 在此寫下你對 Yale Face 影像資料集的分析與實驗過程，譬如：
# - 資料的載入與前處理，例如製做另一組主成分資料供比較之用。
# - 演算法與超參數的選擇與訓練過程。
# - 呈現測試結果，譬如準確度與執行效率，將觀察結果進行討論。
# - 、、、
#
# <hr>

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod>2：統計學習之支援向量機</font>**
#
# 同上、、、
# <hr>

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod> 3：深度學習之神經網路</font>**
#
# 同上、、、
# <hr>

# %% [markdown]
# <hr>
#
# **<font color=darkgoldenrod> 4：深度學習之 Facenet</font>**
#
# 同上、、、
# <hr>

# %% [markdown]
# <hr>
#
# **<font color=darkorange>總結論：</font>**
